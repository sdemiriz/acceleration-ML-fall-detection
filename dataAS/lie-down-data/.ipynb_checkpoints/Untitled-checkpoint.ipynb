# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
path = r'/home/amritpal/sfuhome/falldetection353/fallDetection353/data3/laying' # use your path
all_files = glob.glob(path + "/*.csv")

files_laying = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    files.append(df)

frame = pd.concat(files, axis=0, ignore_index=True)

# %%
path = r'/home/amritpal/sfuhome/falldetection353/fallDetection353/data3/phonefall' # use your path
all_files = glob.glob(path + "/*.csv")

files_phonefall = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    files.append(df)

frame = pd.concat(files, axis=0, ignore_index=True)

# %%
path = r'/home/amritpal/sfuhome/falldetection353/fallDetection353/data3/sit' # use your path
all_files = glob.glob(path + "/*.csv")

files_sit = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    files.append(df)

frame = pd.concat(files, axis=0, ignore_index=True)

# %%
path = r'/home/amritpal/sfuhome/falldetection353/fallDetection353/data3/walkfall' # use your path
all_files = glob.glob(path + "/*.csv")

files_walkfall = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    files.append(df)

frame = pd.concat(files, axis=0, ignore_index=True)

# %%
files_laying
# Out:
# []

# %%
mean_laying_X=np.zeros(20)
mean_laying_Y=np.zeros(20)
mean_laying_Z=np.zeros(20)
for j in range (20):
    mean_laying_X[j]= files_laying[j]['ax (m/s^2)'].mean()
    mean_laying_Y[j]= files_laying[j]['ay (m/s^2)'].mean()
    mean_laying_Z[j]= files_laying[j]['az (m/s^2)'].mean()
    
mean_phonefall_X=np.zeros(20)
mean_phonefall_Y=np.zeros(20)
mean_phonefall_Z=np.zeros(20)
for j in range (20):
    mean_phonefall_X[j]= files_phonefall[j]['ax (m/s^2)'].mean()
    mean_phonefall_Y[j]= files_phonefall[j]['ay (m/s^2)'].mean()
    mean_phonefall_Z[j]= files_phonefall[j]['az (m/s^2)'].mean()
    
mean_sit_X=np.zeros(20)
mean_sit_Y=np.zeros(20)
mean_sit_Z=np.zeros(20)
for j in range (20):
    mean_sit_X[j]= files_sit[j]['ax (m/s^2)'].mean()
    mean_sit_Y[j]= files_sit[j]['ay (m/s^2)'].mean()
    mean_sit_Z[j]= files_sit[j]['az (m/s^2)'].mean()
    
mean_walkfall_X=np.zeros(20)
mean_walkfall_Y=np.zeros(20)
mean_walkfall_Z=np.zeros(20)
for j in range (20):
    mean_walkfall_X[j]= files_walkfall[j]['ax (m/s^2)'].mean()
    mean_walkfall_Y[j]= files_walkfall[j]['ay (m/s^2)'].mean()
    mean_walkfall_Z[j]= files_walkfall[j]['az (m/s^2)'].mean()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-405e34431ed3> in <module>
#       3 mean_laying_Z=np.zeros(20)
#       4 for j in range (20):
# ----> 5     mean_laying_X[j]= files_laying[j]['ax (m/s^2)'].mean()
#       6     mean_laying_Y[j]= files_laying[j]['ay (m/s^2)'].mean()
#       7     mean_laying_Z[j]= files_laying[j]['az (m/s^2)'].mean()
#
# IndexError: list index out of range

# %%
plt.plot(mean_X)
plt.plot(mean_Y)
plt.plot(mean_Z)

# %%
data= pd.read_csv('laying1.csv')
print(data['ax (m/s^2)'].mean())
print(data['ay (m/s^2)'].mean())
print(data['az (m/s^2)'].mean())
print(data['aT (m/s^2)'].mean())
plt.show()
# Out:
# 0.42198590909090933
# -0.339509090909091
# 0.011731909090909163
# 1.9796718181818145

# %%
data2= pd.read_csv('laying2.csv')
plt.plot(data2['ax (m/s^2)'])
plt.plot(data2['ay (m/s^2)'])
plt.plot(data2['az (m/s^2)'])
plt.plot(data2['aT (m/s^2)'])
plt.show()

# %%
data3= pd.read_csv('laying3.csv')
plt.plot(data3['ax (m/s^2)'])
plt.plot(data3['ay (m/s^2)'])
plt.plot(data3['az (m/s^2)'])
plt.plot(data3['aT (m/s^2)'])
plt.show()

# %%
data4= pd.read_csv('laying4.csv')
plt.plot(data4['ax (m/s^2)'])
plt.plot(data4['ay (m/s^2)'])
plt.plot(data4['az (m/s^2)'])
plt.plot(data4['aT (m/s^2)'])
plt.show()
